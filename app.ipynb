# %%
# %pip install langchain
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Aaryan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %pip install -qU langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Aaryan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os

os.environ["GROQ_API_KEY"] = "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"

from langchain_groq import ChatGroq

model = ChatGroq(model="llama3-8b-8192")

# %%
from langchain_core.messages import HumanMessage

model.invoke([HumanMessage(content="Hi! I'm Bob")])
# Out:
# AIMessage(content="Hi Bob! It's nice to meet you. Is there something I can help you with or would you like to chat?", response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 15, 'total_tokens': 41, 'completion_time': 0.019626872, 'prompt_time': 0.004190744, 'queue_time': None, 'total_time': 0.023817616}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-3ebaabd0-5440-40b0-9501-9079336d2eeb-0', usage_metadata={'input_tokens': 15, 'output_tokens': 26, 'total_tokens': 41})

# %%
response = model.invoke([HumanMessage(content="Hi! I'm Bob")])
response.content
# Out:
# "Hi Bob! It's nice to meet you. Is there something I can help you with or would you like to chat?"

# %%
# %pip install fastapi
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# ...
#    ---------------------------------------- 0.0/92.2 kB ? eta -:--:--
#    ---------------------------------------  92.2/92.2 kB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 92.2/92.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    ---------------------------------------- 133.3/133.3 kB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB 3.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
# ...

# %%
# %pip install uvicorn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Aaryan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a Medical assistant. Answer all questions related to medical queries.",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

chain = prompt | model

# %%
response = chain.invoke({"messages": [HumanMessage(content="hi! I'm feeling sick")]})

response.content
# Out:
# "Sorry to hear that you're feeling unwell! As a medical assistant, I'm here to help you figure out what might be going on and what you can do to feel better.\n\nCan you tell me more about what's been going on with your symptoms? For example, what are you experiencing? Are you having trouble breathing, having a fever, or feeling nauseous?"

# %%
with_message_history = RunnableWithMessageHistory(chain, get_session_history)
